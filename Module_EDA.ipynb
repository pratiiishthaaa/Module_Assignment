# %% [raw]
# PRESIDENTIAL ELECTION POLLS 2024 DATASET

# %% [markdown]
# this dataset comprises the results of a nationwide presidential election poll conducted on march 4, 2024. the data offers various insights but does not align with the official election results. you are encouaraged to create your notebooks and derive into the data for futher exploration.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:\\Drive C\\Downloads\\election2024 (2).csv")

# %%
df
# Out:
#                     id     sex   age federal_district  \
# 0     07169ed8148ce047    male  18.0  north caucasian
# 1     0716a4f3354cecdd    male  23.0  north caucasian
# 2     0716889b304ce79c    male  20.0            volga
# 3     07168e28b5cce563    male  22.0     northwestern
# 4     0716a563914ce549    male  21.0         southern
# ...                ...     ...   ...              ...
# 1595  0716b23c2c0cee3a    male  61.0          central
# 1596  07168254d14ceb55  female  80.0            volga
# 1597  071690f34d4ce164  female  76.0     northwestern
# 1598  0716bfa9c48ce79a  female  74.0          central
# 1599  07168088318cef88  female  76.0             ural
#
#                                       type_of_city    knows_election_date  \
# 0                                          village     named correct date
# 1                                          village     named correct date
# 2            city with population of less than 50k     named correct date
# 3     city with population of 1 million and higher  not sure or no answer
# 4     city with population of 1 million and higher     named correct date
# ...                                            ...                    ...
# 1595                                    settlement     named correct date
# 1596                                       village     named correct date
# 1597               city with population of 50-100k     named correct date
# 1598         city with population of less than 50k  not sure or no answer
# 1599                                       village     named correct date
#
#            will_vote           candidate      television_usage  \
# 0           not sure               Putin  several times a week
# 1           not sure               Putin      once half a year
# 2     definitely yes               Putin  several times a week
# 3           not sure            Davankov  several times a week
# 4     definitely yes               Putin        does not watch
# ...              ...                 ...                   ...
# 1595   definitely no  will not take part    over 4 hours a day
# 1596      likely yes  struggle to answer  several times a week
# 1597  definitely yes               Putin        does not watch
# 1598  definitely yes               Putin    over 4 hours a day
# 1599  definitely yes               Putin    over 4 hours a day
#
#                internet_usage                    education       income  \
# 0          over 4 hours a day  incomplete school education    very high
# 1          over 4 hours a day                      college    very high
# 2          over 4 hours a day                      college    very high
# 3          over 4 hours a day                      college    very high
# 4          over 4 hours a day              bachelor degree    very high
# ...                       ...                          ...          ...
# 1595  less than 4 hours a day              bachelor degree  hard to say
# 1596    does not use internet                      college  hard to say
# 1597       over 4 hours a day              bachelor degree  hard to say
# 1598       over 4 hours a day              academic degree  hard to say
# 1599       over 4 hours a day                       school  hard to say
#
#                 employment                 job_type  \
# 0             entrepreneur                      NaN
# 1            work for hire  commercial organization
# 2            work for hire   law enforcement agency
# 3               unemployed                      NaN
# 4         employed student  commercial organization
# ...                    ...                      ...
# 1595  unemployed pensioner                      NaN
# 1596  unemployed pensioner                      NaN
# 1597  unemployed pensioner                      NaN
# 1598    employed pensioner  commercial organization
# 1599  unemployed pensioner                      NaN
#
#                            company_type   weight1
# 0                               farming  1.445172
# 1                                 trade  1.445172
# 2                law enforcement agency  1.301691
# 3                                   NaN  1.538628
# 4     tech, programming, communications  1.967015
# ...                                 ...       ...
# 1595                                NaN  1.270761
# 1596                                NaN  0.921724
# 1597                                NaN  1.396691
# 1598            industry, manufacturing  0.995849
# 1599                                NaN  0.860836
#
# [1600 rows x 16 columns]

# %%
print(df.head())
# Out:
#                  id   sex   age federal_district  \
# 0  07169ed8148ce047  male  18.0  north caucasian
# 1  0716a4f3354cecdd  male  23.0  north caucasian
# 2  0716889b304ce79c  male  20.0            volga
# 3  07168e28b5cce563  male  22.0     northwestern
# 4  0716a563914ce549  male  21.0         southern
#
#                                    type_of_city    knows_election_date  \
# 0                                       village     named correct date
# 1                                       village     named correct date
# 2         city with population of less than 50k     named correct date
# 3  city with population of 1 million and higher  not sure or no answer
# 4  city with population of 1 million and higher     named correct date
#
#         will_vote candidate      television_usage      internet_usage  \
# 0        not sure     Putin  several times a week  over 4 hours a day
# 1        not sure     Putin      once half a year  over 4 hours a day
# 2  definitely yes     Putin  several times a week  over 4 hours a day
# 3        not sure  Davankov  several times a week  over 4 hours a day
# 4  definitely yes     Putin        does not watch  over 4 hours a day
#
#                      education     income        employment  \
# 0  incomplete school education  very high      entrepreneur
# 1                      college  very high     work for hire
# 2                      college  very high     work for hire
# 3                      college  very high        unemployed
# 4              bachelor degree  very high  employed student
#
#                   job_type                       company_type   weight1
# 0                      NaN                            farming  1.445172
# 1  commercial organization                              trade  1.445172
# 2   law enforcement agency             law enforcement agency  1.301691
# 3                      NaN                                NaN  1.538628
# 4  commercial organization  tech, programming, communications  1.967015

# %%
print(df.tail())
# Out:
#                     id     sex   age federal_district  \
# 1595  0716b23c2c0cee3a    male  61.0          central
# 1596  07168254d14ceb55  female  80.0            volga
# 1597  071690f34d4ce164  female  76.0     northwestern
# 1598  0716bfa9c48ce79a  female  74.0          central
# 1599  07168088318cef88  female  76.0             ural
#
#                                type_of_city    knows_election_date  \
# 1595                             settlement     named correct date
# 1596                                village     named correct date
# 1597        city with population of 50-100k     named correct date
# 1598  city with population of less than 50k  not sure or no answer
# 1599                                village     named correct date
#
#            will_vote           candidate      television_usage  \
# 1595   definitely no  will not take part    over 4 hours a day
# 1596      likely yes  struggle to answer  several times a week
# 1597  definitely yes               Putin        does not watch
# 1598  definitely yes               Putin    over 4 hours a day
# 1599  definitely yes               Putin    over 4 hours a day
#
#                internet_usage        education       income  \
# 1595  less than 4 hours a day  bachelor degree  hard to say
# 1596    does not use internet          college  hard to say
# 1597       over 4 hours a day  bachelor degree  hard to say
# 1598       over 4 hours a day  academic degree  hard to say
# 1599       over 4 hours a day           school  hard to say
#
#                 employment                 job_type             company_type  \
# 1595  unemployed pensioner                      NaN                      NaN
# 1596  unemployed pensioner                      NaN                      NaN
# 1597  unemployed pensioner                      NaN                      NaN
# 1598    employed pensioner  commercial organization  industry, manufacturing
# 1599  unemployed pensioner                      NaN                      NaN
#
#        weight1
# 1595  1.270761
# 1596  0.921724
# 1597  1.396691
# 1598  0.995849
# 1599  0.860836

# %%
df.isnull()
# Out:
#          id    sex    age  federal_district  type_of_city  \
# 0     False  False  False             False         False
# 1     False  False  False             False         False
# 2     False  False  False             False         False
# 3     False  False  False             False         False
# 4     False  False  False             False         False
# ...     ...    ...    ...               ...           ...
# 1595  False  False  False             False         False
# 1596  False  False  False             False         False
# 1597  False  False  False             False         False
# 1598  False  False  False             False         False
# 1599  False  False  False             False         False
#
#       knows_election_date  will_vote  candidate  television_usage  \
# 0                   False      False      False             False
# 1                   False      False      False             False
# 2                   False      False      False             False
# 3                   False      False      False             False
# 4                   False      False      False             False
# ...                   ...        ...        ...               ...
# 1595                False      False      False             False
# 1596                False      False      False             False
# 1597                False      False      False             False
# 1598                False      False      False             False
# 1599                False      False      False             False
#
#       internet_usage  education  income  employment  job_type  company_type  \
# 0              False      False   False       False      True         False
# 1              False      False   False       False     False         False
# 2              False      False   False       False     False         False
# 3              False      False   False       False      True          True
# 4              False      False   False       False     False         False
# ...              ...        ...     ...         ...       ...           ...
# 1595           False      False   False       False      True          True
# 1596           False      False   False       False      True          True
# 1597           False      False   False       False      True          True
# 1598           False      False   False       False     False         False
# 1599           False      False   False       False      True          True
#
#       weight1
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ...       ...
# 1595    False
# 1596    False
# 1597    False
# 1598    False
# 1599    False
#
# [1600 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# id                       0
# sex                      0
# age                      0
# federal_district         0
# type_of_city             0
# knows_election_date      0
# will_vote                0
# candidate                0
# television_usage         0
# internet_usage           0
# education                0
# income                   0
# employment               0
# job_type               908
# company_type           721
# weight1                  0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'sex', 'age', 'federal_district', 'type_of_city',
#        'knows_election_date', 'will_vote', 'candidate', 'television_usage',
#        'internet_usage', 'education', 'income', 'employment', 'job_type',
#        'company_type', 'weight1'],
#       dtype='object')

# %%
#display basic information about the dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1600 non-null   object
#  1   sex                  1600 non-null   object
#  2   age                  1600 non-null   float64
#  3   federal_district     1600 non-null   object
#  4   type_of_city         1600 non-null   object
#  5   knows_election_date  1600 non-null   object
#  6   will_vote            1600 non-null   object
#  7   candidate            1600 non-null   object
#  8   television_usage     1600 non-null   object
#  9   internet_usage       1600 non-null   object
#  10  education            1600 non-null   object
#  11  income               1600 non-null   object
#  12  employment           1600 non-null   object
#  13  job_type             692 non-null    object
#  14  company_type         879 non-null    object
#  15  weight1              1600 non-null   float64
# dtypes: float64(2), object(14)
# memory usage: 200.1+ KB

# %%
#display summary statistics
df.describe()
# Out:
#                age      weight1
# count  1600.000000  1600.000000
# mean     49.936250     1.000000
# std      16.901797     0.327084
# min      18.000000     0.468226
# 25%      37.000000     0.772224
# 50%      49.000000     0.921724
# 75%      64.000000     1.158913
# max      90.000000     2.515072

# %%
#check sum missing values.
df.isnull().sum()
# Out:
# id                       0
# sex                      0
# age                      0
# federal_district         0
# type_of_city             0
# knows_election_date      0
# will_vote                0
# candidate                0
# television_usage         0
# internet_usage           0
# education                0
# income                   0
# employment               0
# job_type               908
# company_type           721
# weight1                  0
# dtype: int64

# %%
#fill missing numeric values with the mean
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("D:\\Drive C\\Downloads\\election2024 (2).csv")
numeric_columns = df.select_dtypes(include=[np.number]).columns
df[numeric_columns]=df[numeric_columns].fillna(df[numeric_columns].mean())

# %%
numeric_columns
# Out:
# Index(['age', 'weight1'], dtype='object')

# %%
#fill missing categorical values with the mode
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("D:\\Drive C\\Downloads\\election2024 (2).csv")
data = df.select_dtypes(include=[object]).columns
df[data] = df[data].apply(lambda x: x.fillna(x.mode()[0]))

# %%
data
# Out:
# Index(['id', 'sex', 'federal_district', 'type_of_city', 'knows_election_date',
#        'will_vote', 'candidate', 'television_usage', 'internet_usage',
#        'education', 'income', 'employment', 'job_type', 'company_type'],
#       dtype='object')

# %%
#exploratory data analysis
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("D:\\Drive C\\Downloads\\election2024 (2).csv")
plt.figure(figsize=(10,6))
sns.histplot(df['age'],bins = 30,kde = True)
plt.title("distribution of veter ages")
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#voting preferencies by region
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("D:\\Drive C\\Downloads\\election2024 (2).csv")
print(df.columns)
plt.figure(figsize=(10, 8))
sns.countplot(data=df, x='sex', hue='type_of_city')  
plt.title('Voting Preferences by Region')
plt.xlabel('sex')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.legend(title='type_of_city')
plt.show()
# Out:
# Index(['id', 'sex', 'age', 'federal_district', 'type_of_city',
#        'knows_election_date', 'will_vote', 'candidate', 'television_usage',
#        'internet_usage', 'education', 'income', 'employment', 'job_type',
#        'company_type', 'weight1'],
#       dtype='object')

# %%
print("Unique values in the 'region' column:")
print(df['sex'].unique())

print("Unique values in the 'candidate' column:")
print(df['candidate'].unique())
# Out:
# Unique values in the 'region' column:
# ['male' 'female']
# Unique values in the 'candidate' column:
# ['Putin' 'Davankov' 'will not take part' 'spoilt vote' 'Kharitonov'
#  'struggle to answer' 'Slutskiy']

# %%
#correlation metrics for numeric features
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("D:\\Drive C\\Downloads\\election2024 (2).csv")
print(df.columns)
plt.figure(figsize=(10,8))
# Out:
# Index(['id', 'sex', 'age', 'federal_district', 'type_of_city',
#        'knows_election_date', 'will_vote', 'candidate', 'television_usage',
#        'internet_usage', 'education', 'income', 'employment', 'job_type',
#        'company_type', 'weight1'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("D:\\Drive C\\Downloads\\election2024 (2).csv")
print(df.columns)
numeric_columns = df.select_dtypes(include=[np.number]).columns
df[numeric_columns]=df[numeric_columns].fillna(df[numeric_columns].mean())
plt.figure(figsize=(10,8))
sns.heatmap(df[numeric_columns].corr(),annot=True, cmap='coolwarm')
plt.title('correlation metrix')
plt.show()
# Out:
# Index(['id', 'sex', 'age', 'federal_district', 'type_of_city',
#        'knows_election_date', 'will_vote', 'candidate', 'television_usage',
#        'internet_usage', 'education', 'income', 'employment', 'job_type',
#        'company_type', 'weight1'],
#       dtype='object')

# %%
#gender distribution among voters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("D:\\Drive C\\Downloads\\election2024 (2).csv")
print(df.columns)
numeric_columns = df.select_dtypes(include=[np.number]).columns
df[numeric_columns]=df[numeric_columns].fillna(df[numeric_columns].mean())
plt.figure(figsize=(10,8))
sns.countplot(data = df,x='sex')
plt.title('gender distribution among voters')
plt.show()
# Out:
# Index(['id', 'sex', 'age', 'federal_district', 'type_of_city',
#        'knows_election_date', 'will_vote', 'candidate', 'television_usage',
#        'internet_usage', 'education', 'income', 'employment', 'job_type',
#        'company_type', 'weight1'],
#       dtype='object')

# %%
#average age of voters by candidate
avg_age_by_candidate = df.groupby('candidate')['age'].mean().reset_index()
print("\n average age of voters by candidate:")
print(avg_age_by_candidate)
# Out:
#  average age of voters by candidate:
#             candidate        age
# 0            Davankov  39.059701
# 1          Kharitonov  51.507937
# 2               Putin  51.898050
# 3            Slutskiy  45.127273
# 4         spoilt vote  48.518519
# 5  struggle to answer  45.768293
# 6  will not take part  43.718750

# %%
df
# Out:
#                     id     sex   age federal_district  \
# 0     07169ed8148ce047    male  18.0  north caucasian
# 1     0716a4f3354cecdd    male  23.0  north caucasian
# 2     0716889b304ce79c    male  20.0            volga
# 3     07168e28b5cce563    male  22.0     northwestern
# 4     0716a563914ce549    male  21.0         southern
# ...                ...     ...   ...              ...
# 1595  0716b23c2c0cee3a    male  61.0          central
# 1596  07168254d14ceb55  female  80.0            volga
# 1597  071690f34d4ce164  female  76.0     northwestern
# 1598  0716bfa9c48ce79a  female  74.0          central
# 1599  07168088318cef88  female  76.0             ural
#
#                                       type_of_city    knows_election_date  \
# 0                                          village     named correct date
# 1                                          village     named correct date
# 2            city with population of less than 50k     named correct date
# 3     city with population of 1 million and higher  not sure or no answer
# 4     city with population of 1 million and higher     named correct date
# ...                                            ...                    ...
# 1595                                    settlement     named correct date
# 1596                                       village     named correct date
# 1597               city with population of 50-100k     named correct date
# 1598         city with population of less than 50k  not sure or no answer
# 1599                                       village     named correct date
#
#            will_vote           candidate      television_usage  \
# 0           not sure               Putin  several times a week
# 1           not sure               Putin      once half a year
# 2     definitely yes               Putin  several times a week
# 3           not sure            Davankov  several times a week
# 4     definitely yes               Putin        does not watch
# ...              ...                 ...                   ...
# 1595   definitely no  will not take part    over 4 hours a day
# 1596      likely yes  struggle to answer  several times a week
# 1597  definitely yes               Putin        does not watch
# 1598  definitely yes               Putin    over 4 hours a day
# 1599  definitely yes               Putin    over 4 hours a day
#
#                internet_usage                    education       income  \
# 0          over 4 hours a day  incomplete school education    very high
# 1          over 4 hours a day                      college    very high
# 2          over 4 hours a day                      college    very high
# 3          over 4 hours a day                      college    very high
# 4          over 4 hours a day              bachelor degree    very high
# ...                       ...                          ...          ...
# 1595  less than 4 hours a day              bachelor degree  hard to say
# 1596    does not use internet                      college  hard to say
# 1597       over 4 hours a day              bachelor degree  hard to say
# 1598       over 4 hours a day              academic degree  hard to say
# 1599       over 4 hours a day                       school  hard to say
#
#                 employment                 job_type  \
# 0             entrepreneur                      NaN
# 1            work for hire  commercial organization
# 2            work for hire   law enforcement agency
# 3               unemployed                      NaN
# 4         employed student  commercial organization
# ...                    ...                      ...
# 1595  unemployed pensioner                      NaN
# 1596  unemployed pensioner                      NaN
# 1597  unemployed pensioner                      NaN
# 1598    employed pensioner  commercial organization
# 1599  unemployed pensioner                      NaN
#
#                            company_type   weight1
# 0                               farming  1.445172
# 1                                 trade  1.445172
# 2                law enforcement agency  1.301691
# 3                                   NaN  1.538628
# 4     tech, programming, communications  1.967015
# ...                                 ...       ...
# 1595                                NaN  1.270761
# 1596                                NaN  0.921724
# 1597                                NaN  1.396691
# 1598            industry, manufacturing  0.995849
# 1599                                NaN  0.860836
#
# [1600 rows x 16 columns]

# %%
#voter turnout by income
turnout_by_income = df['income'].value_counts().reset_index()
turnout_by_income.columns = ['income','voter turnout']
print("\nvoter turnout by income:")
print(turnout_by_income)
# Out:
# voter turnout by income:
#         income  voter turnout
# 0       medium            949
# 1         high            405
# 2          low            149
# 3    very high             48
# 4     very low             34
# 5  hard to say             15

# %% [raw]
# EDA on Lung Cancer Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\Pratishtha nanda\\OneDrive\\Documents\\lung_cancer.csv")

# %%
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# 1                   1        2        2         2                  1
# 2                   1        2        1         2                  1
# 3                   2        1        2         1                  1
# 4                   1        2        1         2                  1
# ...               ...      ...      ...       ...                ...
# 2995                2        1        1         1                  1
# 2996                1        2        2         2                  2
# 2997                2        2        2         2                  1
# 2998                2        2        2         2                  2
# 2999                1        1        2         2                  2
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 0            2                    2                      2           1
# 1            1                    1                      2           2
# 2            1                    2                      1           1
# 3            2                    1                      2           2
# 4            1                    1                      1           2
# ...        ...                  ...                    ...         ...
# 2995         2                    1                      1           2
# 2996         1                    1                      2           1
# 2997         1                    2                      2           2
# 2998         1                    2                      1           2
# 2999         1                    1                      1           1
#
#      LUNG_CANCER
# 0             NO
# 1             NO
# 2            YES
# 3            YES
# 4             NO
# ...          ...
# 2995          NO
# 2996          NO
# 2997         YES
# 2998         YES
# 2999         YES
#
# [3000 rows x 16 columns]

# %%
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# 0                    2                      2           1          NO
# 1                    1                      2           2          NO
# 2                    2                      1           1         YES
# 3                    1                      2           2         YES
# 4                    1                      1           2          NO

# %%
df.tail()
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 2995                2        1        1         1                  1
# 2996                1        2        2         2                  2
# 2997                2        2        2         2                  1
# 2998                2        2        2         2                  2
# 2999                1        1        2         2                  2
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 2995         2                    1                      1           2
# 2996         1                    1                      2           1
# 2997         1                    2                      2           2
# 2998         1                    2                      1           2
# 2999         1                    1                      1           1
#
#      LUNG_CANCER
# 2995          NO
# 2996          NO
# 2997         YES
# 2998         YES
# 2999         YES

# %%
df.shape
# Out:
# (3000, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 3000 non-null   object
#  1   AGE                    3000 non-null   int64
#  2   SMOKING                3000 non-null   int64
#  3   YELLOW_FINGERS         3000 non-null   int64
#  4   ANXIETY                3000 non-null   int64
#  5   PEER_PRESSURE          3000 non-null   int64
#  6   CHRONIC_DISEASE        3000 non-null   int64
#  7   FATIGUE                3000 non-null   int64
#  8   ALLERGY                3000 non-null   int64
#  9   WHEEZING               3000 non-null   int64
#  10  ALCOHOL_CONSUMING      3000 non-null   int64
#  11  COUGHING               3000 non-null   int64
#  12  SHORTNESS_OF_BREATH    3000 non-null   int64
#  13  SWALLOWING_DIFFICULTY  3000 non-null   int64
#  14  CHEST_PAIN             3000 non-null   int64
#  15  LUNG_CANCER            3000 non-null   object
# dtypes: int64(14), object(2)
# memory usage: 375.1+ KB

# %%
#get summary stastistics
df.describe()
# Out:
#                AGE      SMOKING  YELLOW_FINGERS      ANXIETY  PEER_PRESSURE  \
# count  3000.000000  3000.000000     3000.000000  3000.000000    3000.000000
# mean     55.169000     1.491000        1.514000     1.494000       1.499000
# std      14.723746     0.500002        0.499887     0.500047       0.500082
# min      30.000000     1.000000        1.000000     1.000000       1.000000
# 25%      42.000000     1.000000        1.000000     1.000000       1.000000
# 50%      55.000000     1.000000        2.000000     1.000000       1.000000
# 75%      68.000000     2.000000        2.000000     2.000000       2.000000
# max      80.000000     2.000000        2.000000     2.000000       2.000000
#
#        CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# count      3000.000000  3000.000000  3000.000000  3000.000000
# mean          1.509667     1.489667     1.506667     1.497333
# std           0.499990     0.499977     0.500039     0.500076
# min           1.000000     1.000000     1.000000     1.000000
# 25%           1.000000     1.000000     1.000000     1.000000
# 50%           2.000000     1.000000     2.000000     1.000000
# 75%           2.000000     2.000000     2.000000     2.000000
# max           2.000000     2.000000     2.000000     2.000000
#
#        ALCOHOL_CONSUMING     COUGHING  SHORTNESS_OF_BREATH  \
# count        3000.000000  3000.000000          3000.000000
# mean            1.491333     1.510667             1.488000
# std             0.500008     0.499970             0.499939
# min             1.000000     1.000000             1.000000
# 25%             1.000000     1.000000             1.000000
# 50%             1.000000     2.000000             1.000000
# 75%             2.000000     2.000000             2.000000
# max             2.000000     2.000000             2.000000
#
#        SWALLOWING_DIFFICULTY   CHEST_PAIN
# count            3000.000000  3000.000000
# mean                1.489667     1.498667
# std                 0.499977     0.500082
# min                 1.000000     1.000000
# 25%                 1.000000     1.000000
# 50%                 1.000000     1.000000
# 75%                 2.000000     2.000000
# max                 2.000000     2.000000

# %%
#check for missing values
df.isnull()
# Out:
#       GENDER    AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      False  False    False           False    False          False
# 1      False  False    False           False    False          False
# 2      False  False    False           False    False          False
# 3      False  False    False           False    False          False
# 4      False  False    False           False    False          False
# ...      ...    ...      ...             ...      ...            ...
# 2995   False  False    False           False    False          False
# 2996   False  False    False           False    False          False
# 2997   False  False    False           False    False          False
# 2998   False  False    False           False    False          False
# 2999   False  False    False           False    False          False
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0               False    False    False     False              False
# 1               False    False    False     False              False
# 2               False    False    False     False              False
# 3               False    False    False     False              False
# 4               False    False    False     False              False
# ...               ...      ...      ...       ...                ...
# 2995            False    False    False     False              False
# 2996            False    False    False     False              False
# 2997            False    False    False     False              False
# 2998            False    False    False     False              False
# 2999            False    False    False     False              False
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 0        False                False                  False       False
# 1        False                False                  False       False
# 2        False                False                  False       False
# 3        False                False                  False       False
# 4        False                False                  False       False
# ...        ...                  ...                    ...         ...
# 2995     False                False                  False       False
# 2996     False                False                  False       False
# 2997     False                False                  False       False
# 2998     False                False                  False       False
# 2999     False                False                  False       False
#
#       LUNG_CANCER
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 2995        False
# 2996        False
# 2997        False
# 2998        False
# 2999        False
#
# [3000 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC_DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL_CONSUMING        0
# COUGHING                 0
# SHORTNESS_OF_BREATH      0
# SWALLOWING_DIFFICULTY    0
# CHEST_PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# Example DataFrame (replace this with your actual DataFrame)
data = {
    'Age': [25, 32, 47, 51, 62, 33],
    'Salary': [50000, 60000, 80000, 90000, 120000, 75000],
    'Name': ['John', 'Jane', 'Jack', 'Jill', 'Joe', 'Jenny']
}
df = pd.DataFrame(data)
# Plotting distributions
sns.histplot(df['Age'], kde=True)
plt.title('Age Distribution')
plt.show()
# Selecting only numeric columns
numeric_df = df.select_dtypes(include=[float, int])
# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Check for relevant columns
required_columns = ['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
       'PEER_PRESSURE']
missing_columns = [col for col in required_columns if col not in df.columns]

if not missing_columns:
    print("Dataset contains all required columns.")
else:
    print(f"Missing columns: {missing_columns}")
# Out:
# Missing columns: ['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY', 'PEER_PRESSURE']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Load your dataset
data_path = "C:\\Users\\Pratishtha nanda\\OneDrive\\Documents\\lung_cancer.csv"
df = pd.read_csv(data_path)
# Display the first few rows to understand the data
print(df.head())

# Keep only numeric columns
numeric_df = df.select_dtypes(include=[float, int])

# Check for and handle any missing values
# For simplicity, we'll fill missing values with the mean of the respective columns
numeric_df.fillna(numeric_df.mean(), inplace=True)

# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# 0                    2                      2           1          NO
# 1                    1                      2           2          NO
# 2                    2                      1           1         YES
# 3                    1                      2           2         YES
# 4                    1                      1           2          NO

# %%
# Keep only numeric columns
numeric_df = df.select_dtypes(include=[float, int])
numeric_df
# Out:
#       AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC_DISEASE  \
# 0      65        1               1        1              2                2
# 1      55        1               2        2              1                1
# 2      78        2               2        1              1                1
# 3      60        2               1        1              1                2
# 4      80        1               1        2              1                1
# ...   ...      ...             ...      ...            ...              ...
# 2995   71        2               1        1              2                2
# 2996   75        1               2        1              1                1
# 2997   62        2               2        2              1                2
# 2998   30        1               1        2              2                2
# 2999   40        1               2        2              1                1
#
#       FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0           1        2         2                  2         2
# 1           2        2         2                  1         1
# 2           2        1         2                  1         1
# 3           1        2         1                  1         2
# 4           2        1         2                  1         1
# ...       ...      ...       ...                ...       ...
# 2995        1        1         1                  1         2
# 2996        2        2         2                  2         1
# 2997        2        2         2                  1         1
# 2998        2        2         2                  2         1
# 2999        1        2         2                  2         1
#
#       SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN
# 0                       2                      2           1
# 1                       1                      2           2
# 2                       2                      1           1
# 3                       1                      2           2
# 4                       1                      1           2
# ...                   ...                    ...         ...
# 2995                    1                      1           2
# 2996                    1                      2           1
# 2997                    2                      2           2
# 2998                    2                      1           2
# 2999                    1                      1           1
#
# [3000 rows x 14 columns]

# %%
numeric_df.fillna(numeric_df.mean(), inplace=True)
numeric_df
# Out:
#       AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC_DISEASE  \
# 0      65        1               1        1              2                2
# 1      55        1               2        2              1                1
# 2      78        2               2        1              1                1
# 3      60        2               1        1              1                2
# 4      80        1               1        2              1                1
# ...   ...      ...             ...      ...            ...              ...
# 2995   71        2               1        1              2                2
# 2996   75        1               2        1              1                1
# 2997   62        2               2        2              1                2
# 2998   30        1               1        2              2                2
# 2999   40        1               2        2              1                1
#
#       FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0           1        2         2                  2         2
# 1           2        2         2                  1         1
# 2           2        1         2                  1         1
# 3           1        2         1                  1         2
# 4           2        1         2                  1         1
# ...       ...      ...       ...                ...       ...
# 2995        1        1         1                  1         2
# 2996        2        2         2                  2         1
# 2997        2        2         2                  1         1
# 2998        2        2         2                  2         1
# 2999        1        2         2                  2         1
#
#       SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN
# 0                       2                      2           1
# 1                       1                      2           2
# 2                       2                      1           1
# 3                       1                      2           2
# 4                       1                      1           2
# ...                   ...                    ...         ...
# 2995                    1                      1           2
# 2996                    1                      2           1
# 2997                    2                      2           2
# 2998                    2                      1           2
# 2999                    1                      1           1
#
# [3000 rows x 14 columns]

# %%
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# 1                   1        2        2         2                  1
# 2                   1        2        1         2                  1
# 3                   2        1        2         1                  1
# 4                   1        2        1         2                  1
# ...               ...      ...      ...       ...                ...
# 2995                2        1        1         1                  1
# 2996                1        2        2         2                  2
# 2997                2        2        2         2                  1
# 2998                2        2        2         2                  2
# 2999                1        1        2         2                  2
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 0            2                    2                      2           1
# 1            1                    1                      2           2
# 2            1                    2                      1           1
# 3            2                    1                      2           2
# 4            1                    1                      1           2
# ...        ...                  ...                    ...         ...
# 2995         2                    1                      1           2
# 2996         1                    1                      2           1
# 2997         1                    2                      2           2
# 2998         1                    2                      1           2
# 2999         1                    1                      1           1
#
#      LUNG_CANCER
# 0             NO
# 1             NO
# 2            YES
# 3            YES
# 4             NO
# ...          ...
# 2995          NO
# 2996          NO
# 2997         YES
# 2998         YES
# 2999         YES
#
# [3000 rows x 16 columns]

# %%
#display data types to identify non-numeric columns
print(df.dtypes)
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC_DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL_CONSUMING         int64
# COUGHING                  int64
# SHORTNESS_OF_BREATH       int64
# SWALLOWING_DIFFICULTY     int64
# CHEST_PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %%
#one-hot encoding categorical variables
data = pd.get_dummies(df,drop_first=True)

# %%
data
# Out:
#       AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC_DISEASE  \
# 0      65        1               1        1              2                2
# 1      55        1               2        2              1                1
# 2      78        2               2        1              1                1
# 3      60        2               1        1              1                2
# 4      80        1               1        2              1                1
# ...   ...      ...             ...      ...            ...              ...
# 2995   71        2               1        1              2                2
# 2996   75        1               2        1              1                1
# 2997   62        2               2        2              1                2
# 2998   30        1               1        2              2                2
# 2999   40        1               2        2              1                1
#
#       FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0           1        2         2                  2         2
# 1           2        2         2                  1         1
# 2           2        1         2                  1         1
# 3           1        2         1                  1         2
# 4           2        1         2                  1         1
# ...       ...      ...       ...                ...       ...
# 2995        1        1         1                  1         2
# 2996        2        2         2                  2         1
# 2997        2        2         2                  1         1
# 2998        2        2         2                  2         1
# 2999        1        2         2                  2         1
#
#       SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  GENDER_M  \
# 0                       2                      2           1      True
# 1                       1                      2           2     False
# 2                       2                      1           1     False
# 3                       1                      2           2      True
# 4                       1                      1           2     False
# ...                   ...                    ...         ...       ...
# 2995                    1                      1           2     False
# 2996                    1                      2           1     False
# 2997                    2                      2           2     False
# 2998                    2                      1           2      True
# 2999                    1                      1           1      True
#
#       LUNG_CANCER_YES
# 0               False
# 1               False
# 2                True
# 3                True
# 4               False
# ...               ...
# 2995            False
# 2996            False
# 2997             True
# 2998             True
# 2999             True
#
# [3000 rows x 16 columns]

# %%
#feature engineering
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)
data = pd.DataFrame(scaled_data,columns=data.columns)

# %%
data
# Out:
#            AGE   SMOKING  YELLOW_FINGERS   ANXIETY  PEER_PRESSURE  \
# 0     0.667808 -0.982159       -1.028403 -0.988071       1.002002
# 1    -0.011480 -0.982159        0.972381  1.012073      -0.998002
# 2     1.550883  1.018165        0.972381 -0.988071      -0.998002
# 3     0.328164  1.018165       -1.028403 -0.988071      -0.998002
# 4     1.686741 -0.982159       -1.028403  1.012073      -0.998002
# ...        ...       ...             ...       ...            ...
# 2995  1.075381  1.018165       -1.028403 -0.988071       1.002002
# 2996  1.347096 -0.982159        0.972381 -0.988071      -0.998002
# 2997  0.464022  1.018165        0.972381  1.012073      -0.998002
# 2998 -1.709700 -0.982159       -1.028403  1.012073       1.002002
# 2999 -1.030412 -0.982159        0.972381  1.012073      -0.998002
#
#       CHRONIC_DISEASE   FATIGUE   ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0            0.980850 -0.979543  0.986754  1.005348           1.017486
# 1           -1.019524  1.020885  0.986754  1.005348          -0.982814
# 2           -1.019524  1.020885 -1.013423  1.005348          -0.982814
# 3            0.980850 -0.979543  0.986754 -0.994681          -0.982814
# 4           -1.019524  1.020885 -1.013423  1.005348          -0.982814
# ...               ...       ...       ...       ...                ...
# 2995         0.980850 -0.979543 -1.013423 -0.994681          -0.982814
# 2996        -1.019524  1.020885  0.986754  1.005348           1.017486
# 2997         0.980850  1.020885  0.986754  1.005348          -0.982814
# 2998         0.980850  1.020885  0.986754  1.005348           1.017486
# 2999        -1.019524 -0.979543  0.986754  1.005348           1.017486
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 0     0.978889             1.024295               1.020885   -0.997337
# 1    -1.021566            -0.976281               1.020885    1.002670
# 2    -1.021566             1.024295              -0.979543   -0.997337
# 3     0.978889            -0.976281               1.020885    1.002670
# 4    -1.021566            -0.976281              -0.979543    1.002670
# ...        ...                  ...                    ...         ...
# 2995  0.978889            -0.976281              -0.979543    1.002670
# 2996 -1.021566            -0.976281               1.020885   -0.997337
# 2997 -1.021566             1.024295               1.020885    1.002670
# 2998 -1.021566             1.024295              -0.979543    1.002670
# 2999 -1.021566            -0.976281              -0.979543   -0.997337
#
#       GENDER_M  LUNG_CANCER_YES
# 0     0.990710        -1.012073
# 1    -1.009377        -1.012073
# 2    -1.009377         0.988071
# 3     0.990710         0.988071
# 4    -1.009377        -1.012073
# ...        ...              ...
# 2995 -1.009377        -1.012073
# 2996 -1.009377        -1.012073
# 2997 -1.009377         0.988071
# 2998  0.990710         0.988071
# 2999  0.990710         0.988071
#
# [3000 rows x 16 columns]

# %%
scaler
# Out:
# StandardScaler()

# %%
scaled_data
# Out:
# array([[ 0.66780823, -0.98215912, -1.02840321, ..., -0.99733688,
#          0.99070982, -1.01207287],
#        [-0.01147997, -0.98215912,  0.97238125, ...,  1.00267023,
#         -1.0093773 , -1.01207287],
#        [ 1.5508829 ,  1.01816496,  0.97238125, ..., -0.99733688,
#         -1.0093773 ,  0.98807114],
#        ...,
#        [ 0.46402177,  1.01816496,  0.97238125, ...,  1.00267023,
#         -1.0093773 ,  0.98807114],
#        [-1.70970048, -0.98215912, -1.02840321, ...,  1.00267023,
#          0.99070982,  0.98807114],
#        [-1.03041227, -0.98215912,  0.97238125, ..., -0.99733688,
#          0.99070982,  0.98807114]])
